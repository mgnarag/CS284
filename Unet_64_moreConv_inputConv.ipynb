# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/machine-learning/blob/main/Unet_64_moreConv_inputConv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/CS284/Project/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

epoch = 100
model_number = 68
size = 64


# Generate augmented images with specific rotations
rotations = [90, 180, 270]
datagen = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.2)




def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.5):
        for i in np.arange(0,int(width/size)+1,0.5):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            #im1 = im1/255
            data.append(im1/255)

            #for rotation:
            im1 = np.expand_dims(im1, axis=0)
            i = 0
            for angle in rotations:
                rotated_image = datagen.apply_transform(im1[0], {'theta': angle})  # Apply specific rotation
                rotated = np.squeeze(rotated_image)
                data.append(rotated/255)
                i += 1
            """
            # Other augmented images
            num_augmented_images = 4  # You can adjust this based on the number of augmentations you want to visualize
            i = 0
            for batch in datagen.flow(im1, batch_size=1):
                x = tf.keras.preprocessing.image.array_to_img(batch[0])
                i += 1
                augmented = np.squeeze(x)
                data.append(augmented/255)
                if i == num_augmented_images:
                    break
            """

    return data



input = np.array(crop(Image.open(file_path + "CROP_WB_ViganII_NAP.png").convert('RGB')))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(Image.open(file_path + "CROP_CLEAN_ViganII_NAP.png").convert('RGB')))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (11664, 64, 64, 3)
# Done reading the output of size =  (11664, 64, 64, 3)
# Done reading the train input of size =  (8748, 64, 64, 3)
# Done reading the test input of size =  (2916, 64, 64, 3)
# Done reading the train output of size =  (8748, 64, 64, 3)
# Done reading the test output of size =  (2916, 64, 64, 3)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)


    plt.title("input")
    plt.imshow((train_input[i+6000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+6000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from tensorflow.keras import layers, losses
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

def unet_model(input_shape=(64, 64, 3)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    #conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    #conv1 = BatchNormalization()(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same', strides = 2)(conv1)
    #conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    #conv2 = BatchNormalization()(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same', strides = 2)(conv2)
    #conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    #conv3 = BatchNormalization()(conv3)

    conv6 = concatenate([Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same')(conv3), conv2], axis = -1)
    #conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
    #conv6 = BatchNormalization()(conv6)

    conv7 = concatenate([Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis = -1)
    #conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)
    #conv7 = BatchNormalization()(conv7)

    # Output Layer
    output = Conv2D(3, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 64)           1792      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)          73856     ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)          147584    ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          295168    ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          590080    ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          295040    ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          295040    ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           73792     ['conv2d_6[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 64)           73792     ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 3)            1731      ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 1884803 (7.19 MB)
# Trainable params: 1884803 (7.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=4)

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'unet_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'val_loss_'+ str(model_number) + '.csv')
# Out:
# Epoch 1/100
# 2187/2187 [==============================] - 45s 14ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 2/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 8.3556e-04 - val_loss: 0.0019
# Epoch 3/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 7.3694e-04 - val_loss: 0.0014
# Epoch 4/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 6.9807e-04 - val_loss: 0.0019
# Epoch 5/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 6.3097e-04 - val_loss: 0.0022
# Epoch 6/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 5.9849e-04 - val_loss: 0.0018
# Epoch 7/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 5.8180e-04 - val_loss: 0.0018
# Epoch 8/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 5.5693e-04 - val_loss: 0.0020
# Epoch 9/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 5.2206e-04 - val_loss: 0.0021
# Epoch 10/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 5.0686e-04 - val_loss: 0.0019
# Epoch 11/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 4.9511e-04 - val_loss: 0.0020
# Epoch 12/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 4.8848e-04 - val_loss: 0.0019
# Epoch 13/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 4.7045e-04 - val_loss: 0.0020
# Epoch 14/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 4.6251e-04 - val_loss: 0.0019
# Epoch 15/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 4.5699e-04 - val_loss: 0.0020
# Epoch 16/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 4.4466e-04 - val_loss: 7.2892e-04
# Epoch 17/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 4.3831e-04 - val_loss: 0.0019
# Epoch 18/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 4.3566e-04 - val_loss: 0.0020
# Epoch 19/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 4.2455e-04 - val_loss: 0.0018
# Epoch 20/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 4.1643e-04 - val_loss: 0.0017
# Epoch 21/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 4.2170e-04 - val_loss: 0.0015
# Epoch 22/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 4.0150e-04 - val_loss: 0.0017
# Epoch 23/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.9658e-04 - val_loss: 0.0019
# Epoch 24/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 3.9246e-04 - val_loss: 0.0017
# Epoch 25/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.9056e-04 - val_loss: 0.0017
# Epoch 26/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 3.8494e-04 - val_loss: 0.0018
# Epoch 27/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 3.7915e-04 - val_loss: 0.0018
# Epoch 28/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.9390e-04 - val_loss: 0.0017
# Epoch 29/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.7553e-04 - val_loss: 0.0015
# Epoch 30/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.6681e-04 - val_loss: 0.0014
# Epoch 31/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.6423e-04 - val_loss: 0.0013
# Epoch 32/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.5894e-04 - val_loss: 0.0011
# Epoch 33/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 3.5668e-04 - val_loss: 0.0011
# Epoch 34/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 3.5316e-04 - val_loss: 9.0005e-04
# Epoch 35/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.4647e-04 - val_loss: 9.5976e-04
# Epoch 36/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 3.4102e-04 - val_loss: 8.1605e-04
# Epoch 37/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 3.3975e-04 - val_loss: 0.0011
# Epoch 38/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.2985e-04 - val_loss: 9.7754e-04
# Epoch 39/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.2337e-04 - val_loss: 9.2917e-04
# Epoch 40/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.1973e-04 - val_loss: 7.6638e-04
# Epoch 41/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.1477e-04 - val_loss: 8.1367e-04
# Epoch 42/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 3.0619e-04 - val_loss: 8.8460e-04
# Epoch 43/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 3.0405e-04 - val_loss: 9.8778e-04
# Epoch 44/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 2.9453e-04 - val_loss: 7.7575e-04
# Epoch 45/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 2.8956e-04 - val_loss: 6.8756e-04
# Epoch 46/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 2.8456e-04 - val_loss: 0.0011
# Epoch 47/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 2.7710e-04 - val_loss: 7.3109e-04
# Epoch 48/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 2.7180e-04 - val_loss: 6.0187e-04
# Epoch 49/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.6671e-04 - val_loss: 7.5760e-04
# Epoch 50/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 2.5986e-04 - val_loss: 6.7252e-04
# Epoch 51/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.5925e-04 - val_loss: 5.9622e-04
# Epoch 52/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.5277e-04 - val_loss: 6.0265e-04
# Epoch 53/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.4784e-04 - val_loss: 5.9564e-04
# Epoch 54/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 2.4389e-04 - val_loss: 5.8779e-04
# Epoch 55/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 2.4248e-04 - val_loss: 5.4405e-04
# Epoch 56/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 2.3441e-04 - val_loss: 6.0990e-04
# Epoch 57/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.3351e-04 - val_loss: 6.1973e-04
# Epoch 58/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.2937e-04 - val_loss: 6.5471e-04
# Epoch 59/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 2.2349e-04 - val_loss: 6.2513e-04
# Epoch 60/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 2.2275e-04 - val_loss: 6.3281e-04
# Epoch 61/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.1641e-04 - val_loss: 5.4436e-04
# Epoch 62/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.1572e-04 - val_loss: 5.3034e-04
# Epoch 63/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 2.1361e-04 - val_loss: 5.5658e-04
# Epoch 64/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.1161e-04 - val_loss: 5.5831e-04
# Epoch 65/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 2.0846e-04 - val_loss: 5.8650e-04
# Epoch 66/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.0578e-04 - val_loss: 5.6538e-04
# Epoch 67/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.0431e-04 - val_loss: 5.4018e-04
# Epoch 68/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 2.0104e-04 - val_loss: 5.4996e-04
# Epoch 69/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 1.9867e-04 - val_loss: 5.7694e-04
# Epoch 70/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.9755e-04 - val_loss: 5.4443e-04
# Epoch 71/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.9690e-04 - val_loss: 5.6184e-04
# Epoch 72/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.9327e-04 - val_loss: 5.7299e-04
# Epoch 73/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.9133e-04 - val_loss: 6.3868e-04
# Epoch 74/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 1.8884e-04 - val_loss: 5.7088e-04
# Epoch 75/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 1.8747e-04 - val_loss: 5.7505e-04
# Epoch 76/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.8701e-04 - val_loss: 5.6260e-04
# Epoch 77/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 1.8478e-04 - val_loss: 6.3456e-04
# Epoch 78/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.8204e-04 - val_loss: 5.5817e-04
# Epoch 79/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 1.8121e-04 - val_loss: 5.6660e-04
# Epoch 80/100
# 2187/2187 [==============================] - 30s 14ms/step - loss: 1.7971e-04 - val_loss: 5.5727e-04
# Epoch 81/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.7652e-04 - val_loss: 5.6412e-04
# Epoch 82/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.7655e-04 - val_loss: 5.6321e-04
# Epoch 83/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.7546e-04 - val_loss: 5.7037e-04
# Epoch 84/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.7226e-04 - val_loss: 5.8249e-04
# Epoch 85/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 1.7170e-04 - val_loss: 5.6756e-04
# Epoch 86/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.7035e-04 - val_loss: 5.9649e-04
# Epoch 87/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.6949e-04 - val_loss: 6.1040e-04
# Epoch 88/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.6923e-04 - val_loss: 5.8916e-04
# Epoch 89/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 1.6657e-04 - val_loss: 5.5655e-04
# Epoch 90/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.6672e-04 - val_loss: 5.8591e-04
# Epoch 91/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.6318e-04 - val_loss: 5.7365e-04
# Epoch 92/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.6289e-04 - val_loss: 5.8186e-04
# Epoch 93/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 1.6461e-04 - val_loss: 5.7935e-04
# Epoch 94/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.6037e-04 - val_loss: 5.5178e-04
# Epoch 95/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.6013e-04 - val_loss: 5.6395e-04
# Epoch 96/100
# 2187/2187 [==============================] - 29s 13ms/step - loss: 1.5863e-04 - val_loss: 5.6833e-04
# Epoch 97/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.5711e-04 - val_loss: 5.7711e-04
# Epoch 98/100
# 2187/2187 [==============================] - 31s 14ms/step - loss: 1.5675e-04 - val_loss: 5.7697e-04
# Epoch 99/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.5664e-04 - val_loss: 5.6397e-04
# Epoch 100/100
# 2187/2187 [==============================] - 28s 13ms/step - loss: 1.5511e-04 - val_loss: 5.7220e-04
# The time of execution of above program is : 2965.451146364212 seconds

# %%
from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np

n_size = 64
def crop_(im):
    width, height = im.size
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data


#filename = str('[WB] 1885_Mactan_NAP_FelixPelayo.png')
#filename = str("1885_Mactan_NAP_FelixPelayo.tiff")
filename = str("[WB] 1872_Mindanao_NAP_D.FedericoCaballero.tif")
#filename = str("[WB] XXXX_Cagayan y Ilocos_online.png")
test = Image.open(file_path+ "Testing nbs/" + filename)
test = test.convert('RGB')
w_dirty, h_dirty = test.size


autoencoder = keras.models.load_model(file_path + 'unet_68_2conv_inputConv')


xx = int(w_dirty/n_size)
final=[]

for portion in range(0,xx):
    im1 = test.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1 = im1.size
    w = int(w1/n_size)
    h = int(h1/n_size)

    neverbeforeseen = np.array(crop_(im1))
    #encoded_imgs = autoencoder.encoder(neverbeforeseen).numpy()
    decoded_imgs = autoencoder.predict(neverbeforeseen)

    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))

    #y = np.where(col > 0.5,1,0) #round the values
    y= col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))

final = np.squeeze(final)
reconstructed = Image.fromarray(final)
reconstructed.save(file_path + "Testing nbs/"+"CLEAN_"+filename)
# Out:
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 25ms/step

# %%
print(np.shape(final))
# Out:
# (6784, 7872)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Load an example image
#img = tf.keras.preprocessing.image.load_img(file_path + "CROP_WB_ViganII_NAP.png")
#x = tf.keras.preprocessing.image.img_to_array(img)
x = train_input[375]
plt.imshow(x)
plt.show()
x = x.reshape((1,) + x.shape)


# Create an instance of the ImageDataGenerator with desired augmentation parameters
datagen = ImageDataGenerator(
    vertical_flip=True,
    horizontal_flip=True,
    zoom_range=0.3,
)

# Generate augmented images with specific rotations
rotations = [90, 180, 270]
num_augmented_images = len(rotations)
i = 0
for angle in rotations:
    augmented_image = datagen.apply_transform(x[0], {'theta': angle})  # Apply specific rotation
    plt.figure(i)
    imgplot = plt.imshow(tf.keras.preprocessing.image.array_to_img(augmented_image))
    i += 1

plt.show()
print("xxxxx")
i = 0
for batch in datagen.flow(x, batch_size=1):
    x = tf.keras.preprocessing.image.array_to_img(batch[0])
    i += 1
    plt.figure(i)
    imgplot = plt.imshow(x)
    if i == 4:
        break
# Out:
# xxxxx

# %%
print(np.shape(x))
# Out:
# (64, 64, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-c7b9648006e8> in <cell line: 1>()
# ----> 1 print(x[0])
#
# TypeError: 'Image' object is not subscriptable
