# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/machine-learning/blob/main/Unet_64_portion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/CS284/Project/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

import cv2

epoch = 100
model_number = 64
size = 64


# Generate augmented images with specific rotations
zoom_factor = [x/5 for x in range(6, 16)]


def zoom_and_resize(img, zoom_factor):
    height, width = img.shape[:2]

    # Calculate the region to crop around the center
    crop_top = int((height - height / zoom_factor) / 2)
    crop_bottom = int(height - crop_top)
    crop_left = int((width - width / zoom_factor) / 2)
    crop_right = int(width - crop_left)
    # Crop the image
    cropped_image = img[crop_top:crop_bottom, crop_left:crop_right]
    # Resize the zoomed image back to the original dimensions
    resized_image = cv2.resize(cropped_image, (width, height))

    return resized_image

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.8):
        for i in np.arange(0,int(width/size)+1,0.8):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            #im1 = im1/255
            data.append(im1/255)
            flip_im1 = np.fliplr(im1)

            rotated_90 = np.rot90(im1)
            data.append(rotated_90/255)
            rotated_90 = np.rot90(rotated_90) #180
            data.append(rotated_90/255)
            rotated_90 = np.rot90(rotated_90) #270
            data.append(rotated_90/255)
            #flip
            rotated_90 = np.rot90(flip_im1)
            data.append(rotated_90/255)
            rotated_90 = np.rot90(rotated_90) #180
            data.append(rotated_90/255)
            rotated_90 = np.rot90(rotated_90) #270
            data.append(rotated_90/255)


            # Define the zoom factor (e.g., 1.2 for 20% zoom in)
            for z in zoom_factor:
                zoomed_img = zoom_and_resize(im1, z)
                data.append(zoomed_img/255)



    return data

data = []

input = np.array(crop(Image.open(file_path + "CROP_WB_ViganII_NAP.png").convert('RGB')))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(Image.open(file_path + "CROP_CLEAN_ViganII_NAP.png").convert('RGB')))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)
input = []

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)

output = []
# Out:
# Done reading the input of size =  (20808, 64, 64, 3)
# Done reading the output of size =  (20808, 64, 64, 3)
# Done reading the train input of size =  (15606, 64, 64, 3)
# Done reading the test input of size =  (5202, 64, 64, 3)
# Done reading the train output of size =  (15606, 64, 64, 3)
# Done reading the test output of size =  (5202, 64, 64, 3)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)


    plt.title("input")
    plt.imshow((train_input[i+7500]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+7500]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization
from tensorflow.keras import layers, losses
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate

def unet_model(input_shape=(64, 64, 3)):
    inputs = Input(input_shape)

    # Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    #conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    #conv1 = BatchNormalization()(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same', strides = 2)(conv1)
    #conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    #conv2 = BatchNormalization()(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same', strides = 2)(conv2)
    #conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    #conv3 = BatchNormalization()(conv3)

    conv6 = concatenate([Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same')(conv3), conv2], axis = -1)
    #conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
    #conv6 = BatchNormalization()(conv6)

    conv7 = concatenate([Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same')(conv6), conv1], axis = -1)
    #conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(64, 3, activation='relu', padding='same')(conv7)
    #conv7 = BatchNormalization()(conv7)

    # Output Layer
    output = Conv2D(3, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv7)

    model = Model(inputs=inputs, outputs=output)
    return model

# Usage example:
unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 64)           1792      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)          73856     ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)          147584    ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          295168    ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          590080    ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          295040    ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          295040    ['concatenate[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           73792     ['conv2d_6[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 64)           73792     ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 3)            1731      ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 1884803 (7.19 MB)
# Trainable params: 1884803 (7.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.0001)
unet.compile(optimizer=opt, loss=losses.MeanSquaredError())
start = time.time()
model = unet.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output),batch_size=16)

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")

unet.save(file_path + 'unet_' + str(model_number)+"_portion")

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + 'loss_'+ str(model_number)+"_portion" + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path  +'val_loss_'+ str(model_number)+"_portion" + '.csv')
# Out:
# Epoch 1/100
# 976/976 [==============================] - 50s 41ms/step - loss: 0.0096 - val_loss: 9.4480e-04
# Epoch 2/100
# 976/976 [==============================] - 38s 39ms/step - loss: 9.0026e-04 - val_loss: 7.9803e-04
# Epoch 3/100
# 976/976 [==============================] - 38s 39ms/step - loss: 7.5631e-04 - val_loss: 7.0513e-04
# Epoch 4/100
# 976/976 [==============================] - 40s 41ms/step - loss: 6.8482e-04 - val_loss: 6.0050e-04
# Epoch 5/100
# 976/976 [==============================] - 38s 39ms/step - loss: 6.6154e-04 - val_loss: 5.6845e-04
# Epoch 6/100
# 976/976 [==============================] - 39s 40ms/step - loss: 6.2415e-04 - val_loss: 5.5398e-04
# Epoch 7/100
# 976/976 [==============================] - 40s 41ms/step - loss: 6.0203e-04 - val_loss: 6.1133e-04
# Epoch 8/100
# 976/976 [==============================] - 40s 41ms/step - loss: 5.7858e-04 - val_loss: 5.5630e-04
# Epoch 9/100
# 976/976 [==============================] - 40s 41ms/step - loss: 5.5283e-04 - val_loss: 5.5432e-04
# Epoch 10/100
# 976/976 [==============================] - 39s 40ms/step - loss: 5.2339e-04 - val_loss: 5.0716e-04
# Epoch 11/100
# 976/976 [==============================] - 40s 41ms/step - loss: 5.0580e-04 - val_loss: 6.5139e-04
# Epoch 12/100
# 976/976 [==============================] - 38s 39ms/step - loss: 5.1436e-04 - val_loss: 4.9653e-04
# Epoch 13/100
# 976/976 [==============================] - 40s 41ms/step - loss: 4.7096e-04 - val_loss: 4.5832e-04
# Epoch 14/100
# 976/976 [==============================] - 40s 41ms/step - loss: 4.6597e-04 - val_loss: 4.8271e-04
# Epoch 15/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.8380e-04 - val_loss: 6.7896e-04
# Epoch 16/100
# 976/976 [==============================] - 40s 41ms/step - loss: 5.1084e-04 - val_loss: 4.5262e-04
# Epoch 17/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.3541e-04 - val_loss: 4.3075e-04
# Epoch 18/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.2890e-04 - val_loss: 4.3978e-04
# Epoch 19/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.2687e-04 - val_loss: 4.1552e-04
# Epoch 20/100
# 976/976 [==============================] - 39s 40ms/step - loss: 4.2679e-04 - val_loss: 5.0323e-04
# Epoch 21/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.1716e-04 - val_loss: 3.9273e-04
# Epoch 22/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.0037e-04 - val_loss: 3.9735e-04
# Epoch 23/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.9766e-04 - val_loss: 4.2372e-04
# Epoch 24/100
# 976/976 [==============================] - 39s 39ms/step - loss: 4.0198e-04 - val_loss: 3.9353e-04
# Epoch 25/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.9922e-04 - val_loss: 3.9072e-04
# Epoch 26/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.9018e-04 - val_loss: 3.7137e-04
# Epoch 27/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.7893e-04 - val_loss: 3.7304e-04
# Epoch 28/100
# 976/976 [==============================] - 38s 39ms/step - loss: 4.1505e-04 - val_loss: 3.7457e-04
# Epoch 29/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.7000e-04 - val_loss: 3.6852e-04
# Epoch 30/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.6706e-04 - val_loss: 3.6258e-04
# Epoch 31/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.6892e-04 - val_loss: 3.7185e-04
# Epoch 32/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.6430e-04 - val_loss: 3.6192e-04
# Epoch 33/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.6084e-04 - val_loss: 3.5965e-04
# Epoch 34/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.9258e-04 - val_loss: 3.6959e-04
# Epoch 35/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.5389e-04 - val_loss: 3.5623e-04
# Epoch 36/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.5300e-04 - val_loss: 3.5149e-04
# Epoch 37/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.6351e-04 - val_loss: 3.6525e-04
# Epoch 38/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.5336e-04 - val_loss: 3.5009e-04
# Epoch 39/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.4611e-04 - val_loss: 3.7072e-04
# Epoch 40/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.4244e-04 - val_loss: 3.8431e-04
# Epoch 41/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.4288e-04 - val_loss: 3.5347e-04
# Epoch 42/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.4539e-04 - val_loss: 3.6577e-04
# Epoch 43/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.4022e-04 - val_loss: 3.4000e-04
# Epoch 44/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.3524e-04 - val_loss: 3.4460e-04
# Epoch 45/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.3867e-04 - val_loss: 3.5368e-04
# Epoch 46/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.3298e-04 - val_loss: 3.3505e-04
# Epoch 47/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.2809e-04 - val_loss: 3.3492e-04
# Epoch 48/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.3052e-04 - val_loss: 3.3539e-04
# Epoch 49/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.3216e-04 - val_loss: 3.2988e-04
# Epoch 50/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.2599e-04 - val_loss: 3.3413e-04
# Epoch 51/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.2210e-04 - val_loss: 3.5940e-04
# Epoch 52/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.2280e-04 - val_loss: 3.3628e-04
# Epoch 53/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.2462e-04 - val_loss: 3.3270e-04
# Epoch 54/100
# 976/976 [==============================] - 39s 39ms/step - loss: 3.1890e-04 - val_loss: 3.2684e-04
# Epoch 55/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.1770e-04 - val_loss: 3.3771e-04
# Epoch 56/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.1702e-04 - val_loss: 3.2585e-04
# Epoch 57/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.1792e-04 - val_loss: 3.2794e-04
# Epoch 58/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.1464e-04 - val_loss: 3.2098e-04
# Epoch 59/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.1196e-04 - val_loss: 3.2240e-04
# Epoch 60/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.1014e-04 - val_loss: 3.1752e-04
# Epoch 61/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.1047e-04 - val_loss: 3.2349e-04
# Epoch 62/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.0865e-04 - val_loss: 3.3858e-04
# Epoch 63/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.0605e-04 - val_loss: 3.1551e-04
# Epoch 64/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.0433e-04 - val_loss: 3.2564e-04
# Epoch 65/100
# 976/976 [==============================] - 39s 40ms/step - loss: 3.0581e-04 - val_loss: 3.3187e-04
# Epoch 66/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.0306e-04 - val_loss: 3.2133e-04
# Epoch 67/100
# 976/976 [==============================] - 38s 39ms/step - loss: 3.0077e-04 - val_loss: 3.2464e-04
# Epoch 68/100
# 976/976 [==============================] - 40s 41ms/step - loss: 3.0244e-04 - val_loss: 3.1015e-04
# Epoch 69/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.9842e-04 - val_loss: 3.2412e-04
# Epoch 70/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.9722e-04 - val_loss: 3.1073e-04
# Epoch 71/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.9582e-04 - val_loss: 3.0846e-04
# Epoch 72/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.9605e-04 - val_loss: 3.0467e-04
# Epoch 73/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.9331e-04 - val_loss: 3.2440e-04
# Epoch 74/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.9260e-04 - val_loss: 3.0526e-04
# Epoch 75/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.8945e-04 - val_loss: 3.0941e-04
# Epoch 76/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.8921e-04 - val_loss: 3.0006e-04
# Epoch 77/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.8987e-04 - val_loss: 3.1317e-04
# Epoch 78/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.8613e-04 - val_loss: 3.0211e-04
# Epoch 79/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.8770e-04 - val_loss: 3.0940e-04
# Epoch 80/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.8331e-04 - val_loss: 3.0249e-04
# Epoch 81/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.8258e-04 - val_loss: 2.9639e-04
# Epoch 82/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.8154e-04 - val_loss: 3.0006e-04
# Epoch 83/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.8079e-04 - val_loss: 3.0144e-04
# Epoch 84/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.7716e-04 - val_loss: 2.9425e-04
# Epoch 85/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.7591e-04 - val_loss: 3.0264e-04
# Epoch 86/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.7718e-04 - val_loss: 3.0247e-04
# Epoch 87/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.7552e-04 - val_loss: 2.9676e-04
# Epoch 88/100
# 976/976 [==============================] - 39s 40ms/step - loss: 2.7600e-04 - val_loss: 3.1288e-04
# Epoch 89/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.7021e-04 - val_loss: 2.9486e-04
# Epoch 90/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.7070e-04 - val_loss: 2.9619e-04
# Epoch 91/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.7007e-04 - val_loss: 2.9223e-04
# Epoch 92/100
# 976/976 [==============================] - 39s 40ms/step - loss: 2.6721e-04 - val_loss: 2.9264e-04
# Epoch 93/100
# 976/976 [==============================] - 39s 40ms/step - loss: 2.6919e-04 - val_loss: 3.1247e-04
# Epoch 94/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.6517e-04 - val_loss: 3.0773e-04
# Epoch 95/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.6599e-04 - val_loss: 2.9242e-04
# Epoch 96/100
# 976/976 [==============================] - 39s 40ms/step - loss: 2.6210e-04 - val_loss: 2.9055e-04
# Epoch 97/100
# 976/976 [==============================] - 39s 40ms/step - loss: 2.5988e-04 - val_loss: 2.8381e-04
# Epoch 98/100
# 976/976 [==============================] - 40s 41ms/step - loss: 2.6024e-04 - val_loss: 2.9070e-04
# Epoch 99/100
# 976/976 [==============================] - 39s 40ms/step - loss: 2.5804e-04 - val_loss: 2.9277e-04
# Epoch 100/100
# 976/976 [==============================] - 38s 39ms/step - loss: 2.5615e-04 - val_loss: 2.8626e-04
# The time of execution of above program is : 3907.4863109588623 seconds

# %%
from tensorflow import keras
from PIL import Image, ImageOps
import numpy as np
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 236958876

n_size = 64
def crop_(im):
    width, height = im.size
    data = []
    for j in range(0,int(height/n_size)):
        for i in range(0,int(width/n_size)):
            im1 = im.crop((0 + (n_size*i), 0 + (n_size*j), n_size + (n_size*i), n_size + (n_size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data


#filename = str('[WB] 1885_Mactan_NAP_FelixPelayo.png')
#filename = str("1885_Mactan_NAP_FelixPelayo.tiff")
#filename = str("[WB] 1872_Mindanao_NAP_D.FedericoCaballero.tif")
#filename = str("[WB] XXXX_Cagayan y Ilocos_online.png")
filename = str("[WB] XXXX_Manila_NAP_Hoja2.tiff")
test = Image.open(file_path+ "Testing nbs/" + filename)
test = test.convert('RGB')
w_dirty, h_dirty = test.size


autoencoder = keras.models.load_model(file_path + 'unet_64_portion')


xx = int(w_dirty/n_size)
final=[]

for portion in range(0,xx):
    im1 = test.crop((n_size*portion, 0, (n_size*portion) + n_size, h_dirty))
    w1, h1 = im1.size
    w = int(w1/n_size)
    h = int(h1/n_size)

    neverbeforeseen = np.array(crop_(im1))
    #encoded_imgs = autoencoder.encoder(neverbeforeseen).numpy()
    decoded_imgs = autoencoder.predict(neverbeforeseen)

    col = np.vstack((decoded_imgs[0],decoded_imgs[1]))
    for i in range(2,h):
        col = np.vstack((col,decoded_imgs[i]))

    #y = np.where(col > 0.5,1,0) #round the values
    y= col
    y = (y * 255).astype('uint8')
    if portion == 0:
        final = y
    if portion > 0:
        final = np.hstack((final,y))

final = np.squeeze(final)
reconstructed = Image.fromarray(final)
reconstructed.save(file_path + "Testing nbs/"+"CLEAN_"+filename)
# Out:
# 7/7 [==============================] - 1s 192ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 21ms/step
# 7/7 [==============================] - 0s 22ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 16ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 24ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 23ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 23ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 23ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 21ms/step
# 7/7 [==============================] - 0s 22ms/step
# 7/7 [==============================] - 0s 24ms/step
# 7/7 [==============================] - 0s 22ms/step
# 7/7 [==============================] - 0s 22ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 21ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 20ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 19ms/step
# 7/7 [==============================] - 0s 18ms/step
# 7/7 [==============================] - 0s 18ms/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Load an example image
#img = tf.keras.preprocessing.image.load_img(file_path + "CROP_WB_ViganII_NAP.png")
#x = tf.keras.preprocessing.image.img_to_array(img)
x = train_input[1]
plt.imshow(x)
plt.show()
x = x.reshape((1,) + x.shape)
print(x)


# Create an instance of the ImageDataGenerator with desired augmentation parameters
datagen = ImageDataGenerator(
    zoom_range=[0.8, 1.2],  # Specifies the range for random zoom
    rescale=1./255  # Optional: rescale pixel values
)

# Generate augmented images with specific rotations
rotations = [45,135, 225]
num_augmented_images = len(rotations)
i = 0

for angle in rotations:
    augmented_image = datagen.apply_transform(x[0], {'theta': angle})  # Apply specific rotation
    plt.figure(i)
    imgplot = plt.imshow(tf.keras.preprocessing.image.array_to_img(augmented_image))
    i += 1


plt.show()
print("xxxxx")
"""
i = 0
for batch in datagen.flow(x, batch_size=1):
    x = tf.keras.preprocessing.image.array_to_img(batch[0])
    i += 1
    plt.figure(i)
    imgplot = plt.imshow(x)
    if i == 4:
        break
"""

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import zoom

# Load an example image
x = train_input[1]
img = x

# Convert the image to a NumPy array
img_array = image.img_to_array(img)

# Define the zoom factor (e.g., 1.2 for 20% zoom in)
zoom_factor = 1.2

# Zoom in on the image without changing pixel intensities
zoomed_img_array = zoom(img_array, [zoom_factor, zoom_factor, 1], order=0, mode='nearest')
#zoomed_img_array = np.resize(zoomed_img_array, (64,64))
# Clip values to be in the valid range [0, 255]
#zoomed_img_array = np.clip(zoomed_img_array, 0, 255)

# Convert back to uint8
#zoomed_img_array = zoomed_img_array.astype(np.uint8)

# Display the original and zoomed images
plt.figure(figsize=(8, 4))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title('Original Image')
plt.axis('off')

# Zoomed image
plt.subplot(1, 2, 2)
plt.imshow(zoomed_img_array)
plt.title('Zoomed Image')
plt.axis('off')

plt.show()
